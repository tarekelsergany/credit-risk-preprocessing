# %% [markdown]
# # Install Libraries and Dataset Importing

# %%
#importing libraries
import pandas as pd 
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#importing the dataset
data = pd.read_csv("German credit risk.csv")

# %% [markdown]
# # Data Preparation and preprocessing

# %%
#checking the shape of the dataset
data.shape
# Out:
# (5000, 21)

# %%
#checking the info of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CheckingStatus            5000 non-null   object
#  1   LoanDuration              5000 non-null   int64
#  2   CreditHistory             5000 non-null   object
#  3   LoanPurpose               5000 non-null   object
#  4   LoanAmount                5000 non-null   int64
#  5   ExistingSavings           5000 non-null   object
#  6   EmploymentDuration        5000 non-null   object
#  7   InstallmentPercent        5000 non-null   int64
#  8   Sex                       5000 non-null   object
#  9   OthersOnLoan              5000 non-null   object
#  10  CurrentResidenceDuration  5000 non-null   int64
#  11  OwnsProperty              5000 non-null   object
#  12  Age                       5000 non-null   int64
#  13  InstallmentPlans          5000 non-null   object
#  14  Housing                   5000 non-null   object
#  15  ExistingCreditsCount      5000 non-null   int64
#  16  Job                       5000 non-null   object
#  17  Dependents                5000 non-null   int64
#  18  Telephone                 5000 non-null   object
#  19  ForeignWorker             5000 non-null   object
#  20  Risk                      5000 non-null   object
# dtypes: int64(7), object(14)
# memory usage: 820.4+ KB

# %%
#checking how many unique values
data.nunique()
# Out:
# CheckingStatus                 4
# LoanDuration                  59
# CreditHistory                  5
# LoanPurpose                   11
# LoanAmount                  3354
# ExistingSavings                5
# EmploymentDuration             5
# InstallmentPercent             6
# Sex                            2
# OthersOnLoan                   3
# CurrentResidenceDuration       6
# OwnsProperty                   4
# Age                           53
# InstallmentPlans               3
# Housing                        3
# ExistingCreditsCount           4
# Job                            4
# Dependents                     2
# Telephone                      2
# ForeignWorker                  2
# Risk                           2
# dtype: int64

# %%
#checking the duplicates values
data.duplicated().sum()
# Out:
# 18

# %%
#remove the duplicates values
data=data.drop_duplicates()

# %%
data
# Out:
#      CheckingStatus  LoanDuration           CreditHistory LoanPurpose  \
# 0          0_to_200            31    credits_paid_to_date       other
# 1            less_0            18    credits_paid_to_date     car_new
# 2            less_0            15  prior_payments_delayed   furniture
# 3          0_to_200            28    credits_paid_to_date  retraining
# 4       no_checking            28  prior_payments_delayed   education
# ...             ...           ...                     ...         ...
# 4995    greater_200            27    credits_paid_to_date   furniture
# 4996       0_to_200            11  prior_payments_delayed   furniture
# 4997    no_checking            32      outstanding_credit  appliances
# 4998       0_to_200            38      outstanding_credit       other
# 4999         less_0            12   all_credits_paid_back     car_new
#
#       LoanAmount ExistingSavings EmploymentDuration  InstallmentPercent  \
# 0           1889      100_to_500             less_1                   3
# 1            462        less_100             1_to_4                   2
# 2            250        less_100             1_to_4                   2
# 3           3693        less_100          greater_7                   3
# 4           6235     500_to_1000          greater_7                   3
# ...          ...             ...                ...                 ...
# 4995        4650        less_100             1_to_4                   3
# 4996         250    greater_1000             4_to_7                   3
# 4997        6536         unknown          greater_7                   5
# 4998        1597     500_to_1000          greater_7                   3
# 4999        4152        less_100             1_to_4                   2
#
#          Sex  OthersOnLoan  ...       OwnsProperty Age  InstallmentPlans  \
# 0     female          none  ...  savings_insurance  32              none
# 1     female          none  ...  savings_insurance  37            stores
# 2       male          none  ...        real_estate  28              none
# 3       male          none  ...  savings_insurance  32              none
# 4       male          none  ...            unknown  57              none
# ...      ...           ...  ...                ...  ..               ...
# 4995    male          none  ...  savings_insurance  40              none
# 4996    male          none  ...          car_other  32              bank
# 4997    male  co-applicant  ...            unknown  54            stores
# 4998  female  co-applicant  ...  savings_insurance  27            stores
# 4999    male          none  ...  savings_insurance  29              none
#
#      Housing ExistingCreditsCount         Job Dependents  Telephone  \
# 0        own                    1     skilled          1       none
# 1        own                    2     skilled          1       none
# 2        own                    2     skilled          1        yes
# 3        own                    1     skilled          1       none
# 4        own                    2     skilled          1       none
# ...      ...                  ...         ...        ...        ...
# 4995     own                    1     skilled          1       none
# 4996     own                    1  unemployed          1       none
# 4997     own                    2   unskilled          2        yes
# 4998     own                    1     skilled          1       none
# 4999     own                    2     skilled          1       none
#
#      ForeignWorker     Risk
# 0              yes  No Risk
# 1              yes  No Risk
# 2               no  No Risk
# 3              yes  No Risk
# 4              yes     Risk
# ...            ...      ...
# 4995           yes  No Risk
# 4996           yes  No Risk
# 4997           yes     Risk
# 4998           yes     Risk
# 4999           yes  No Risk
#
# [4982 rows x 21 columns]

# %%
#checking the messing values
data.isnull().sum()
# Out:
# CheckingStatus              0
# LoanDuration                0
# CreditHistory               0
# LoanPurpose                 0
# LoanAmount                  0
# ExistingSavings             0
# EmploymentDuration          0
# InstallmentPercent          0
# Sex                         0
# OthersOnLoan                0
# CurrentResidenceDuration    0
# OwnsProperty                0
# Age                         0
# InstallmentPlans            0
# Housing                     0
# ExistingCreditsCount        0
# Job                         0
# Dependents                  0
# Telephone                   0
# ForeignWorker               0
# Risk                        0
# dtype: int64

# %%
#checking the outliers
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data = data, orient="v", palette="tab10" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xticks(rotation=45)
plt.xlabel("Attributes", fontweight = 'bold');

# %%
#checking the statistical features of the dataset
data.describe()
# Out:
#        LoanDuration    LoanAmount  InstallmentPercent  \
# count   4982.000000   4982.000000         4982.000000
# mean      21.455841   3491.815536            2.989562
# std       11.133832   2485.122687            1.122801
# min        4.000000    250.000000            1.000000
# 25%       13.000000   1345.500000            2.000000
# 50%       21.000000   3250.500000            3.000000
# 75%       30.000000   5358.750000            4.000000
# max       64.000000  11676.000000            6.000000
#
#        CurrentResidenceDuration          Age  ExistingCreditsCount  \
# count               4982.000000  4982.000000           4982.000000
# mean                   2.859093    35.993577              1.467483
# std                    1.114332    10.618910              0.565741
# min                    1.000000    19.000000              1.000000
# 25%                    2.000000    28.000000              1.000000
# 50%                    3.000000    36.000000              1.000000
# 75%                    4.000000    44.000000              2.000000
# max                    6.000000    74.000000              4.000000
#
#         Dependents
# count  4982.000000
# mean      1.165195
# std       0.371393
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000

# %%
#checking the names of the columns
data.columns
# Out:
# Index(['CheckingStatus', 'LoanDuration', 'CreditHistory', 'LoanPurpose',
#        'LoanAmount', 'ExistingSavings', 'EmploymentDuration',
#        'InstallmentPercent', 'Sex', 'OthersOnLoan', 'CurrentResidenceDuration',
#        'OwnsProperty', 'Age', 'InstallmentPlans', 'Housing',
#        'ExistingCreditsCount', 'Job', 'Dependents', 'Telephone',
#        'ForeignWorker', 'Risk'],
#       dtype='object')

# %%
#getting better understanding of the dataset and knowing what is the unique values
for i in data.columns:
    print(f"{i} count : {data[i].nunique()}")
    print(f"{data[i].unique()}\n")
# Out:
# CheckingStatus count : 4
# ['0_to_200' 'less_0' 'no_checking' 'greater_200']
#
# LoanDuration count : 59
# [31 18 15 28 32  9 16 11 35  5 27 29  4 33 39 13 34 23 10 25 20 26 21  7
#  14 64  6 19 17 38  8 30 22 37 12 36 50 41 24 43 40 48 46 44 42 45 53 61
#  51 63 47 54 49 60 59 56 62 57 52]
#
# CreditHistory count : 5
# ['credits_paid_to_date' 'prior_payments_delayed' 'outstanding_credit'
#  'all_credits_paid_back' 'no_credits']
#
# LoanPurpose count : 11
# ['other' 'car_new' 'furniture' 'retraining' 'education' 'vacation'
#  'appliances' 'car_used' 'repairs' 'radio_tv' 'business']
#
# LoanAmount count : 3354
# [1889  462  250 ... 6536 1597 4152]
#
# ExistingSavings count : 5
# ['100_to_500' 'less_100' '500_to_1000' 'unknown' 'greater_1000']
#
# EmploymentDuration count : 5
# ['less_1' '1_to_4' 'greater_7' '4_to_7' 'unemployed']
#
# InstallmentPercent count : 6
# [3 2 6 5 4 1]
#
# Sex count : 2
# ['female' 'male']
#
# OthersOnLoan count : 3
# ['none' 'co-applicant' 'guarantor']
#
# CurrentResidenceDuration count : 6
# [3 2 5 4 1 6]
#
# OwnsProperty count : 4
# ['savings_insurance' 'real_estate' 'unknown' 'car_other']
#
# Age count : 53
# [32 37 28 57 41 36 22 49 19 34 40 44 52 35 26 27 24 33 51 38 46 31 39 29
#  45 25 59 55 42 54 20 50 30 47 53 43 48 23 56 21 60 70 61 62 58 65 66 74
#  63 71 67 73 64]
#
# InstallmentPlans count : 3
# ['none' 'stores' 'bank']
#
# Housing count : 3
# ['own' 'free' 'rent']
#
# ExistingCreditsCount count : 4
# [1 2 3 4]
#
# Job count : 4
# ['skilled' 'management_self-employed' 'unskilled' 'unemployed']
#
# Dependents count : 2
# [1 2]
#
# Telephone count : 2
# ['none' 'yes']
#
# ForeignWorker count : 2
# ['yes' 'no']
#
# Risk count : 2
# ['No Risk' 'Risk']

# %%
# label encoding for the target column
label_encoder = preprocessing.LabelEncoder()
data['Risk']= label_encoder.fit_transform(data['Risk'])
data['Risk'].unique()
# Out:
# array([0, 1])

# %%
data
# Out:
#      CheckingStatus  LoanDuration           CreditHistory LoanPurpose  \
# 0          0_to_200            31    credits_paid_to_date       other
# 1            less_0            18    credits_paid_to_date     car_new
# 2            less_0            15  prior_payments_delayed   furniture
# 3          0_to_200            28    credits_paid_to_date  retraining
# 4       no_checking            28  prior_payments_delayed   education
# ...             ...           ...                     ...         ...
# 4995    greater_200            27    credits_paid_to_date   furniture
# 4996       0_to_200            11  prior_payments_delayed   furniture
# 4997    no_checking            32      outstanding_credit  appliances
# 4998       0_to_200            38      outstanding_credit       other
# 4999         less_0            12   all_credits_paid_back     car_new
#
#       LoanAmount ExistingSavings EmploymentDuration  InstallmentPercent  \
# 0           1889      100_to_500             less_1                   3
# 1            462        less_100             1_to_4                   2
# 2            250        less_100             1_to_4                   2
# 3           3693        less_100          greater_7                   3
# 4           6235     500_to_1000          greater_7                   3
# ...          ...             ...                ...                 ...
# 4995        4650        less_100             1_to_4                   3
# 4996         250    greater_1000             4_to_7                   3
# 4997        6536         unknown          greater_7                   5
# 4998        1597     500_to_1000          greater_7                   3
# 4999        4152        less_100             1_to_4                   2
#
#          Sex  OthersOnLoan  ...       OwnsProperty Age  InstallmentPlans  \
# 0     female          none  ...  savings_insurance  32              none
# 1     female          none  ...  savings_insurance  37            stores
# 2       male          none  ...        real_estate  28              none
# 3       male          none  ...  savings_insurance  32              none
# 4       male          none  ...            unknown  57              none
# ...      ...           ...  ...                ...  ..               ...
# 4995    male          none  ...  savings_insurance  40              none
# 4996    male          none  ...          car_other  32              bank
# 4997    male  co-applicant  ...            unknown  54            stores
# 4998  female  co-applicant  ...  savings_insurance  27            stores
# 4999    male          none  ...  savings_insurance  29              none
#
#      Housing ExistingCreditsCount         Job Dependents  Telephone  \
# 0        own                    1     skilled          1       none
# 1        own                    2     skilled          1       none
# 2        own                    2     skilled          1        yes
# 3        own                    1     skilled          1       none
# 4        own                    2     skilled          1       none
# ...      ...                  ...         ...        ...        ...
# 4995     own                    1     skilled          1       none
# 4996     own                    1  unemployed          1       none
# 4997     own                    2   unskilled          2        yes
# 4998     own                    1     skilled          1       none
# 4999     own                    2     skilled          1       none
#
#      ForeignWorker Risk
# 0              yes    0
# 1              yes    0
# 2               no    0
# 3              yes    0
# 4              yes    1
# ...            ...  ...
# 4995           yes    0
# 4996           yes    0
# 4997           yes    1
# 4998           yes    1
# 4999           yes    0
#
# [4982 rows x 21 columns]

# %%
# age groups labeling
data['Age_Group'] = np.nan
lst = [data]

for col in lst:
    col.loc[(col['Age'] >= 19) & (col['Age'] <= 29), 'Age_Group'] = 'Young'
    col.loc[(col['Age'] > 29) & (col['Age'] <= 40), 'Age_Group'] = 'Adults'
    col.loc[(col['Age'] > 40) & (col['Age'] <= 55), 'Age_Group'] = 'Senior'
    col.loc[col['Age'] > 55, 'Age_Group'] = 'Elder' 
data.head()
# Out:
#   CheckingStatus  LoanDuration           CreditHistory LoanPurpose  \
# 0       0_to_200            31    credits_paid_to_date       other
# 1         less_0            18    credits_paid_to_date     car_new
# 2         less_0            15  prior_payments_delayed   furniture
# 3       0_to_200            28    credits_paid_to_date  retraining
# 4    no_checking            28  prior_payments_delayed   education
#
#    LoanAmount ExistingSavings EmploymentDuration  InstallmentPercent     Sex  \
# 0        1889      100_to_500             less_1                   3  female
# 1         462        less_100             1_to_4                   2  female
# 2         250        less_100             1_to_4                   2    male
# 3        3693        less_100          greater_7                   3    male
# 4        6235     500_to_1000          greater_7                   3    male
#
#   OthersOnLoan  ...  Age InstallmentPlans  Housing ExistingCreditsCount  \
# 0         none  ...   32             none      own                    1
# 1         none  ...   37           stores      own                    2
# 2         none  ...   28             none      own                    2
# 3         none  ...   32             none      own                    1
# 4         none  ...   57             none      own                    2
#
#        Job  Dependents Telephone  ForeignWorker Risk Age_Group
# 0  skilled           1      none            yes    0    Adults
# 1  skilled           1      none            yes    0    Adults
# 2  skilled           1       yes             no    0     Young
# 3  skilled           1      none            yes    0    Adults
# 4  skilled           1      none            yes    1     Elder
#
# [5 rows x 22 columns]

# %%
# ExistingSavings groups labeling
data['ExistingSavings_Group'] = data["ExistingSavings"].map({'less_100':'little', '100_to_500':'moderate' ,"500_to_1000":"quite_rich" ,"greater_1000":'rich' })

# %%
# CheckingStatus groups labeling
data['CheckingStatus_Group'] = data["CheckingStatus"].map({'less_0':'fair', '0_to_200':'moderate' ,"greater_200":"rich" ,"no_checking":'no_checking' })

# %%
data
# Out:
#      CheckingStatus  LoanDuration           CreditHistory LoanPurpose  \
# 0          0_to_200            31    credits_paid_to_date       other
# 1            less_0            18    credits_paid_to_date     car_new
# 2            less_0            15  prior_payments_delayed   furniture
# 3          0_to_200            28    credits_paid_to_date  retraining
# 4       no_checking            28  prior_payments_delayed   education
# ...             ...           ...                     ...         ...
# 4995    greater_200            27    credits_paid_to_date   furniture
# 4996       0_to_200            11  prior_payments_delayed   furniture
# 4997    no_checking            32      outstanding_credit  appliances
# 4998       0_to_200            38      outstanding_credit       other
# 4999         less_0            12   all_credits_paid_back     car_new
#
#       LoanAmount ExistingSavings EmploymentDuration  InstallmentPercent  \
# 0           1889      100_to_500             less_1                   3
# 1            462        less_100             1_to_4                   2
# 2            250        less_100             1_to_4                   2
# 3           3693        less_100          greater_7                   3
# 4           6235     500_to_1000          greater_7                   3
# ...          ...             ...                ...                 ...
# 4995        4650        less_100             1_to_4                   3
# 4996         250    greater_1000             4_to_7                   3
# 4997        6536         unknown          greater_7                   5
# 4998        1597     500_to_1000          greater_7                   3
# 4999        4152        less_100             1_to_4                   2
#
#          Sex  OthersOnLoan  ...  Housing ExistingCreditsCount         Job  \
# 0     female          none  ...      own                    1     skilled
# 1     female          none  ...      own                    2     skilled
# 2       male          none  ...      own                    2     skilled
# 3       male          none  ...      own                    1     skilled
# 4       male          none  ...      own                    2     skilled
# ...      ...           ...  ...      ...                  ...         ...
# 4995    male          none  ...      own                    1     skilled
# 4996    male          none  ...      own                    1  unemployed
# 4997    male  co-applicant  ...      own                    2   unskilled
# 4998  female  co-applicant  ...      own                    1     skilled
# 4999    male          none  ...      own                    2     skilled
#
#      Dependents Telephone  ForeignWorker Risk  Age_Group  \
# 0             1      none            yes    0     Adults
# 1             1      none            yes    0     Adults
# 2             1       yes             no    0      Young
# 3             1      none            yes    0     Adults
# 4             1      none            yes    1      Elder
# ...         ...       ...            ...  ...        ...
# 4995          1      none            yes    0     Adults
# 4996          1      none            yes    0     Adults
# 4997          2       yes            yes    1     Senior
# 4998          1      none            yes    1      Young
# 4999          1      none            yes    0      Young
#
#      ExistingSavings_Group CheckingStatus_Group
# 0                 moderate             moderate
# 1                   little                 fair
# 2                   little                 fair
# 3                   little             moderate
# 4               quite_rich          no_checking
# ...                    ...                  ...
# 4995                little                 rich
# 4996                  rich             moderate
# 4997                   NaN          no_checking
# 4998            quite_rich             moderate
# 4999                little                 fair
#
# [4982 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4982 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CheckingStatus            4982 non-null   object
#  1   LoanDuration              4982 non-null   int64
#  2   CreditHistory             4982 non-null   object
#  3   LoanPurpose               4982 non-null   object
#  4   LoanAmount                4982 non-null   int64
#  5   ExistingSavings           4982 non-null   object
#  6   EmploymentDuration        4982 non-null   object
#  7   InstallmentPercent        4982 non-null   int64
#  8   Sex                       4982 non-null   object
#  9   OthersOnLoan              4982 non-null   object
#  10  CurrentResidenceDuration  4982 non-null   int64
#  11  OwnsProperty              4982 non-null   object
#  12  Age                       4982 non-null   int64
#  13  InstallmentPlans          4982 non-null   object
#  14  Housing                   4982 non-null   object
#  15  ExistingCreditsCount      4982 non-null   int64
#  16  Job                       4982 non-null   object
#  17  Dependents                4982 non-null   int64
#  18  Telephone                 4982 non-null   object
#  19  ForeignWorker             4982 non-null   object
#  20  Risk                      4982 non-null   int64
#  21  Age_Group                 4982 non-null   object
#  22  ExistingSavings_Group     4607 non-null   object
#  23  CheckingStatus_Group      4982 non-null   object
# dtypes: int64(8), object(16)
# memory usage: 973.0+ KB

# %% [markdown]
# <h2 style="color:maroon"> dealing with categorical variables </h2>

# %%
categorical_cols = ['CheckingStatus_Group', 'CreditHistory', 'LoanPurpose', 'ExistingSavings_Group','EmploymentDuration','Sex','OthersOnLoan','OwnsProperty','InstallmentPlans','Housing','Job','ForeignWorker','Age_Group']
aa=pd.get_dummies(data, columns=categorical_cols)

aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4982 entries, 0 to 4999
# Data columns (total 65 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CheckingStatus                        4982 non-null   object
#  1   LoanDuration                          4982 non-null   int64
#  2   LoanAmount                            4982 non-null   int64
#  3   ExistingSavings                       4982 non-null   object
#  4   InstallmentPercent                    4982 non-null   int64
#  5   CurrentResidenceDuration              4982 non-null   int64
#  6   Age                                   4982 non-null   int64
#  7   ExistingCreditsCount                  4982 non-null   int64
#  8   Dependents                            4982 non-null   int64
#  9   Telephone                             4982 non-null   object
#  10  Risk                                  4982 non-null   int64
#  11  CheckingStatus_Group_fair             4982 non-null   uint8
#  12  CheckingStatus_Group_moderate         4982 non-null   uint8
#  13  CheckingStatus_Group_no_checking      4982 non-null   uint8
#  14  CheckingStatus_Group_rich             4982 non-null   uint8
#  15  CreditHistory_all_credits_paid_back   4982 non-null   uint8
#  16  CreditHistory_credits_paid_to_date    4982 non-null   uint8
#  17  CreditHistory_no_credits              4982 non-null   uint8
#  18  CreditHistory_outstanding_credit      4982 non-null   uint8
#  19  CreditHistory_prior_payments_delayed  4982 non-null   uint8
#  20  LoanPurpose_appliances                4982 non-null   uint8
#  21  LoanPurpose_business                  4982 non-null   uint8
#  22  LoanPurpose_car_new                   4982 non-null   uint8
#  23  LoanPurpose_car_used                  4982 non-null   uint8
#  24  LoanPurpose_education                 4982 non-null   uint8
#  25  LoanPurpose_furniture                 4982 non-null   uint8
#  26  LoanPurpose_other                     4982 non-null   uint8
#  27  LoanPurpose_radio_tv                  4982 non-null   uint8
#  28  LoanPurpose_repairs                   4982 non-null   uint8
#  29  LoanPurpose_retraining                4982 non-null   uint8
#  30  LoanPurpose_vacation                  4982 non-null   uint8
#  31  ExistingSavings_Group_little          4982 non-null   uint8
#  32  ExistingSavings_Group_moderate        4982 non-null   uint8
#  33  ExistingSavings_Group_quite_rich      4982 non-null   uint8
#  34  ExistingSavings_Group_rich            4982 non-null   uint8
#  35  EmploymentDuration_1_to_4             4982 non-null   uint8
#  36  EmploymentDuration_4_to_7             4982 non-null   uint8
#  37  EmploymentDuration_greater_7          4982 non-null   uint8
#  38  EmploymentDuration_less_1             4982 non-null   uint8
#  39  EmploymentDuration_unemployed         4982 non-null   uint8
#  40  Sex_female                            4982 non-null   uint8
#  41  Sex_male                              4982 non-null   uint8
#  42  OthersOnLoan_co-applicant             4982 non-null   uint8
#  43  OthersOnLoan_guarantor                4982 non-null   uint8
#  44  OthersOnLoan_none                     4982 non-null   uint8
#  45  OwnsProperty_car_other                4982 non-null   uint8
#  46  OwnsProperty_real_estate              4982 non-null   uint8
#  47  OwnsProperty_savings_insurance        4982 non-null   uint8
#  48  OwnsProperty_unknown                  4982 non-null   uint8
#  49  InstallmentPlans_bank                 4982 non-null   uint8
#  50  InstallmentPlans_none                 4982 non-null   uint8
#  51  InstallmentPlans_stores               4982 non-null   uint8
#  52  Housing_free                          4982 non-null   uint8
#  53  Housing_own                           4982 non-null   uint8
#  54  Housing_rent                          4982 non-null   uint8
#  55  Job_management_self-employed          4982 non-null   uint8
#  56  Job_skilled                           4982 non-null   uint8
#  57  Job_unemployed                        4982 non-null   uint8
#  58  Job_unskilled                         4982 non-null   uint8
#  59  ForeignWorker_no                      4982 non-null   uint8
#  60  ForeignWorker_yes                     4982 non-null   uint8
#  61  Age_Group_Adults                      4982 non-null   uint8
#  62  Age_Group_Elder                       4982 non-null   uint8
#  63  Age_Group_Senior                      4982 non-null   uint8
#  64  Age_Group_Young                       4982 non-null   uint8
# dtypes: int64(8), object(3), uint8(54)
# memory usage: 729.8+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4982 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CheckingStatus            4982 non-null   object
#  1   LoanDuration              4982 non-null   int64
#  2   CreditHistory             4982 non-null   object
#  3   LoanPurpose               4982 non-null   object
#  4   LoanAmount                4982 non-null   int64
#  5   ExistingSavings           4982 non-null   object
#  6   EmploymentDuration        4982 non-null   object
#  7   InstallmentPercent        4982 non-null   int64
#  8   Sex                       4982 non-null   object
#  9   OthersOnLoan              4982 non-null   object
#  10  CurrentResidenceDuration  4982 non-null   int64
#  11  OwnsProperty              4982 non-null   object
#  12  Age                       4982 non-null   int64
#  13  InstallmentPlans          4982 non-null   object
#  14  Housing                   4982 non-null   object
#  15  ExistingCreditsCount      4982 non-null   int64
#  16  Job                       4982 non-null   object
#  17  Dependents                4982 non-null   int64
#  18  Telephone                 4982 non-null   object
#  19  ForeignWorker             4982 non-null   object
#  20  Risk                      4982 non-null   int64
#  21  Age_Group                 4982 non-null   object
#  22  ExistingSavings_Group     4607 non-null   object
#  23  CheckingStatus_Group      4982 non-null   object
# dtypes: int64(8), object(16)
# memory usage: 973.0+ KB

# %%
bb= aa.drop(columns=["CheckingStatus","ExistingSavings","Age" ,"Telephone"])
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4982 entries, 0 to 4999
# Data columns (total 61 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   LoanDuration                          4982 non-null   int64
#  1   LoanAmount                            4982 non-null   int64
#  2   InstallmentPercent                    4982 non-null   int64
#  3   CurrentResidenceDuration              4982 non-null   int64
#  4   ExistingCreditsCount                  4982 non-null   int64
#  5   Dependents                            4982 non-null   int64
#  6   Risk                                  4982 non-null   int64
#  7   CheckingStatus_Group_fair             4982 non-null   uint8
#  8   CheckingStatus_Group_moderate         4982 non-null   uint8
#  9   CheckingStatus_Group_no_checking      4982 non-null   uint8
#  10  CheckingStatus_Group_rich             4982 non-null   uint8
#  11  CreditHistory_all_credits_paid_back   4982 non-null   uint8
#  12  CreditHistory_credits_paid_to_date    4982 non-null   uint8
#  13  CreditHistory_no_credits              4982 non-null   uint8
#  14  CreditHistory_outstanding_credit      4982 non-null   uint8
#  15  CreditHistory_prior_payments_delayed  4982 non-null   uint8
#  16  LoanPurpose_appliances                4982 non-null   uint8
#  17  LoanPurpose_business                  4982 non-null   uint8
#  18  LoanPurpose_car_new                   4982 non-null   uint8
#  19  LoanPurpose_car_used                  4982 non-null   uint8
#  20  LoanPurpose_education                 4982 non-null   uint8
#  21  LoanPurpose_furniture                 4982 non-null   uint8
#  22  LoanPurpose_other                     4982 non-null   uint8
#  23  LoanPurpose_radio_tv                  4982 non-null   uint8
#  24  LoanPurpose_repairs                   4982 non-null   uint8
#  25  LoanPurpose_retraining                4982 non-null   uint8
#  26  LoanPurpose_vacation                  4982 non-null   uint8
#  27  ExistingSavings_Group_little          4982 non-null   uint8
#  28  ExistingSavings_Group_moderate        4982 non-null   uint8
#  29  ExistingSavings_Group_quite_rich      4982 non-null   uint8
#  30  ExistingSavings_Group_rich            4982 non-null   uint8
#  31  EmploymentDuration_1_to_4             4982 non-null   uint8
#  32  EmploymentDuration_4_to_7             4982 non-null   uint8
#  33  EmploymentDuration_greater_7          4982 non-null   uint8
#  34  EmploymentDuration_less_1             4982 non-null   uint8
#  35  EmploymentDuration_unemployed         4982 non-null   uint8
#  36  Sex_female                            4982 non-null   uint8
#  37  Sex_male                              4982 non-null   uint8
#  38  OthersOnLoan_co-applicant             4982 non-null   uint8
#  39  OthersOnLoan_guarantor                4982 non-null   uint8
#  40  OthersOnLoan_none                     4982 non-null   uint8
#  41  OwnsProperty_car_other                4982 non-null   uint8
#  42  OwnsProperty_real_estate              4982 non-null   uint8
#  43  OwnsProperty_savings_insurance        4982 non-null   uint8
#  44  OwnsProperty_unknown                  4982 non-null   uint8
#  45  InstallmentPlans_bank                 4982 non-null   uint8
#  46  InstallmentPlans_none                 4982 non-null   uint8
#  47  InstallmentPlans_stores               4982 non-null   uint8
#  48  Housing_free                          4982 non-null   uint8
#  49  Housing_own                           4982 non-null   uint8
#  50  Housing_rent                          4982 non-null   uint8
#  51  Job_management_self-employed          4982 non-null   uint8
#  52  Job_skilled                           4982 non-null   uint8
#  53  Job_unemployed                        4982 non-null   uint8
#  54  Job_unskilled                         4982 non-null   uint8
#  55  ForeignWorker_no                      4982 non-null   uint8
#  56  ForeignWorker_yes                     4982 non-null   uint8
#  57  Age_Group_Adults                      4982 non-null   uint8
#  58  Age_Group_Elder                       4982 non-null   uint8
#  59  Age_Group_Senior                      4982 non-null   uint8
#  60  Age_Group_Young                       4982 non-null   uint8
# dtypes: int64(7), uint8(54)
# memory usage: 574.1 KB

# %%
cor_data = bb.corr()

# %%
import seaborn as sns

sns.heatmap(cor_data,linewidths=2,cmap="viridis")

# %% [markdown]
# -----------

# %%
#pd.DataFrame(y).value_counts()

# %% [markdown]
# <h2 style="color:maroon">Apply PCA on the original data after daeling with the categorical variables</h2>

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay,plot_confusion_matrix
from sklearn import preprocessing

# %%
X = bb.drop('Risk', axis=1)
y = bb['Risk'].values

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(X, y)

# %% [markdown]
# ------

# %%
def perform_PCA_TEST(model,X,y):
    for i in [3,4,5,6,7,8,9,11,15,20,25,30]:
        pca = PCA(n_components=i,random_state=0)
        PCA_data = pca.fit_transform(X)

        X_train, X_test, y_train, y_test = train_test_split(PCA_data,y, test_size=0.2, shuffle=True, stratify = y, random_state=0)    
#         scaler = preprocessing.StandardScaler()
#         X_train = scaler.fit_transform(X_train)
#         X_test = scaler.transform(X_test)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        print(f"component :{i}")
        print(classification_report(y_test,y_pred,labels=model.classes_))
        
        print("===========================")

# %%
xg = GradientBoostingClassifier(n_estimators=500, random_state=0)
perform_PCA_TEST(xg,X_resampled, y_resampled)
# Out:
# component :3
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74       663
#            1       0.73      0.80      0.76       662
#
#     accuracy                           0.75      1325
#    macro avg       0.76      0.75      0.75      1325
# weighted avg       0.76      0.75      0.75      1325
#
# ===========================
# component :4
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76       663
#            1       0.74      0.82      0.78       662
#
#     accuracy                           0.77      1325
#    macro avg       0.77      0.77      0.77      1325
# weighted avg       0.77      0.77      0.77      1325
#
# ===========================
# component :5
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75       663
#            1       0.74      0.80      0.77       662
#
#     accuracy                           0.76      1325
#    macro avg       0.76      0.76      0.76      1325
# weighted avg       0.76      0.76      0.76      1325
#
# ===========================
# component :6
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       663
#            1       0.75      0.78      0.77       662
#
#     accuracy                           0.76      1325
#    macro avg       0.76      0.76      0.76      1325
# weighted avg       0.76      0.76      0.76      1325
#
# ===========================
# component :7
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77       663
#            1       0.76      0.81      0.79       662
#
#     accuracy                           0.78      1325
#    macro avg       0.78      0.78      0.78      1325
# weighted avg       0.78      0.78      0.78      1325
#
# ===========================
# component :8
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.77       663
#            1       0.75      0.82      0.79       662
#
#     accuracy                           0.78      1325
#    macro avg       0.78      0.78      0.78      1325
# weighted avg       0.78      0.78      0.78      1325
#
# ===========================
# component :9
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78       663
#            1       0.77      0.82      0.80       662
#
#     accuracy                           0.79      1325
#    macro avg       0.79      0.79      0.79      1325
# weighted avg       0.79      0.79      0.79      1325
#
# ===========================
# component :11
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       663
#            1       0.80      0.86      0.82       662
#
#     accuracy                           0.82      1325
#    macro avg       0.82      0.82      0.82      1325
# weighted avg       0.82      0.82      0.82      1325
#
# ===========================
# component :15
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       663
#            1       0.80      0.85      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :20
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80       663
#            1       0.78      0.85      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.81      0.81      0.81      1325
# weighted avg       0.81      0.81      0.81      1325
#
# ===========================
# component :25
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       663
#            1       0.79      0.86      0.82       662
#
#     accuracy                           0.82      1325
#    macro avg       0.82      0.82      0.82      1325
# weighted avg       0.82      0.82      0.82      1325
#
# ===========================
# component :30
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81       663
#            1       0.79      0.88      0.83       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325
#
# ===========================

# %% [markdown]
# ----------

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0).fit(X, y)
perform_PCA_TEST(clf,X_resampled, y_resampled)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# component :3
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       663
#            1       0.71      0.74      0.73       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :4
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       663
#            1       0.71      0.74      0.72       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :5
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71       663
#            1       0.71      0.73      0.72       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :6
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       663
#            1       0.71      0.72      0.72       662
#
#     accuracy                           0.71      1325
#    macro avg       0.71      0.71      0.71      1325
# weighted avg       0.71      0.71      0.71      1325
#
# ===========================
# component :7
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72       663
#            1       0.72      0.72      0.72       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :8
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72       663
#            1       0.72      0.72      0.72       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :9
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73       663
#            1       0.72      0.74      0.73       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :11
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73       663
#            1       0.73      0.73      0.73       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :15
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73       663
#            1       0.74      0.71      0.73       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :20
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       663
#            1       0.73      0.74      0.74       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# component :25
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       663
#            1       0.73      0.74      0.74       662
#
#     accuracy                           0.74      1325
#    macro avg       0.74      0.74      0.74      1325
# weighted avg       0.74      0.74      0.74      1325
#
# ===========================
# component :30
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       663
#            1       0.73      0.74      0.74       662
#
#     accuracy                           0.74      1325
#    macro avg       0.74      0.74      0.74      1325
# weighted avg       0.74      0.74      0.74      1325
#
# ===========================
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# ----------

# %%
ada = AdaBoostClassifier(n_estimators=300, random_state=0)
perform_PCA_TEST(ada,X_resampled, y_resampled)
# Out:
# component :3
#               precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70       663
#            1       0.69      0.76      0.73       662
#
#     accuracy                           0.71      1325
#    macro avg       0.72      0.71      0.71      1325
# weighted avg       0.72      0.71      0.71      1325
#
# ===========================
# component :4
#               precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71       663
#            1       0.71      0.77      0.74       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :5
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72       663
#            1       0.71      0.75      0.73       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :6
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       663
#            1       0.72      0.74      0.73       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :7
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       663
#            1       0.72      0.74      0.73       662
#
#     accuracy                           0.72      1325
#    macro avg       0.72      0.72      0.72      1325
# weighted avg       0.72      0.72      0.72      1325
#
# ===========================
# component :8
#               precision    recall  f1-score   support
#
#            0       0.74      0.71      0.72       663
#            1       0.72      0.75      0.74       662
#
#     accuracy                           0.73      1325
#    macro avg       0.73      0.73      0.73      1325
# weighted avg       0.73      0.73      0.73      1325
#
# ===========================
# component :9
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73       663
#            1       0.73      0.77      0.75       662
#
#     accuracy                           0.74      1325
#    macro avg       0.74      0.74      0.74      1325
# weighted avg       0.74      0.74      0.74      1325
#
# ===========================
# component :11
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.74       663
#            1       0.74      0.77      0.75       662
#
#     accuracy                           0.75      1325
#    macro avg       0.75      0.75      0.75      1325
# weighted avg       0.75      0.75      0.75      1325
#
# ===========================
# component :15
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       663
#            1       0.74      0.78      0.76       662
#
#     accuracy                           0.75      1325
#    macro avg       0.75      0.75      0.75      1325
# weighted avg       0.75      0.75      0.75      1325
#
# ===========================
# component :20
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.76       663
#            1       0.75      0.80      0.77       662
#
#     accuracy                           0.76      1325
#    macro avg       0.77      0.76      0.76      1325
# weighted avg       0.77      0.76      0.76      1325
#
# ===========================
# component :25
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.76       663
#            1       0.76      0.76      0.76       662
#
#     accuracy                           0.76      1325
#    macro avg       0.76      0.76      0.76      1325
# weighted avg       0.76      0.76      0.76      1325
#
# ===========================
# component :30
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.77       663
#            1       0.76      0.81      0.78       662
#
#     accuracy                           0.77      1325
#    macro avg       0.77      0.77      0.77      1325
# weighted avg       0.77      0.77      0.77      1325
#
# ===========================

# %% [markdown]
# -------

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier(random_state=0)
perform_PCA_TEST(dt,X_resampled, y_resampled)
# Out:
# component :3
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78       663
#            1       0.75      0.89      0.81       662
#
#     accuracy                           0.80      1325
#    macro avg       0.81      0.80      0.80      1325
# weighted avg       0.81      0.80      0.80      1325
#
# ===========================
# component :4
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       663
#            1       0.76      0.90      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :5
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       663
#            1       0.76      0.89      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :6
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80       663
#            1       0.77      0.89      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :7
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78       663
#            1       0.76      0.89      0.82       662
#
#     accuracy                           0.80      1325
#    macro avg       0.81      0.80      0.80      1325
# weighted avg       0.81      0.80      0.80      1325
#
# ===========================
# component :8
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       663
#            1       0.77      0.90      0.83       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :9
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80       663
#            1       0.78      0.90      0.83       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325
#
# ===========================
# component :11
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81       663
#            1       0.78      0.90      0.84       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325
#
# ===========================
# component :15
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.79       663
#            1       0.76      0.90      0.82       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.80      1325
# weighted avg       0.82      0.81      0.80      1325
#
# ===========================
# component :20
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       663
#            1       0.77      0.87      0.81       662
#
#     accuracy                           0.80      1325
#    macro avg       0.81      0.80      0.80      1325
# weighted avg       0.81      0.80      0.80      1325
#
# ===========================
# component :25
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.80       663
#            1       0.77      0.89      0.83       662
#
#     accuracy                           0.81      1325
#    macro avg       0.82      0.81      0.81      1325
# weighted avg       0.82      0.81      0.81      1325
#
# ===========================
# component :30
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81       663
#            1       0.78      0.90      0.83       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325
#
# ===========================

# %% [markdown]
# -------------------------------

# %%
pca = PCA(n_components=11,random_state=0)
PCA_data = pca.fit_transform(X_resampled)

# %% [markdown]
# <h2 style="color:maroon"> split the data to train , test  </h2>

# %%
X_train, X_test, y_train, y_test = train_test_split(PCA_data, y_resampled, test_size=0.2, shuffle=True, stratify = y_resampled, random_state=0)

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier(random_state=0)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)

# %%
print(classification_report(y_test,y_pred,labels=ada.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81       663
#            1       0.78      0.90      0.84       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325

# %% [markdown]
# ----------

# %% [markdown]
# <h2 style="color:maroon"> Buid ADA-boost classifier </h2>

# %%
ada = AdaBoostClassifier(n_estimators=300, random_state=0)
ada.fit(X_train, y_train)
y_pred = ada.predict(X_test)

# %%
print(classification_report(y_test,y_pred,labels=ada.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81       663
#            1       0.78      0.90      0.84       662
#
#     accuracy                           0.82      1325
#    macro avg       0.83      0.82      0.82      1325
# weighted avg       0.83      0.82      0.82      1325

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm)
cm_display.plot()
plt.show()

# %% [markdown]
# ---------------

# %% [markdown]
# <h2 style="color:maroon"> Buid XG-boost classifier </h2>

# %%
xg = GradientBoostingClassifier(n_estimators=500, random_state=0)
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)

# %%
print(classification_report(y_test,y_pred,labels=xg.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       663
#            1       0.80      0.86      0.82       662
#
#     accuracy                           0.82      1325
#    macro avg       0.82      0.82      0.82      1325
# weighted avg       0.82      0.82      0.82      1325

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm)
cm_display.plot()
plt.show()

# %% [markdown]
# --------

# %%
import openpyxl as xls

# %%
excel = pd.ExcelWriter("G3.credit_risk.xlsx")

# %%
data.to_excel(excel)

# %%
excel.save()

# %%
#RMF
#STANDERSCALER preprocessing

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = preprocessing.StandardScaler()
#bb[bb.columns] = scaler.fit_transform(bb[bb.columns])
